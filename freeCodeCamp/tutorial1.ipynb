# %% [markdown]
# 2. Write the command used to import the PySpark library after installation.

# %%
import pyspark

# %% [markdown]
# 3. How do you import the Pandas library, and how can you verify the data type returned by reading a CSV file using pandas.read_csv()?

# %%
import pandas as pd
df_p = pd.read_csv("test1.csv")
type(df_p)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 4. Write the statement required to import SparkSession from the PySpark SQL module.

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# 5. How do you create a SparkSession with a custom application name called "Practise"?

# %%
spark = SparkSession.builder.appName("Practise").getOrCreate()

# %% [markdown]
# 6. Write the command used to display the SparkSession object after it has been created.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://WIN-TBM2Q8JSFF6.lan:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Amith</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# 7. How can you read a CSV file into a PySpark DataFrame without specifying any additional options?

# %%
df = spark.read.csv("test1.csv")
df.show()
# Out:
# +---------+---+----------+------+
# |      _c0|_c1|       _c2|   _c3|
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# 8. Write the statement used to read a CSV file with a header using PySpark.

# %%
df = spark.read.csv("test1.csv",header=True)
df.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# 9. How do you check the type of a PySpark DataFrame after loading data from a CSV file?

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# 10. What command is used to print the schema of a PySpark DataFrame?

# %%
df.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- Experience: string (nullable = true)
#  |-- Salary: string (nullable = true)
