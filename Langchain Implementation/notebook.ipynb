# %%
import bs4
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 8
#       6 from langchain_core.output_parsers import StrOutputParser
#       7 from langchain_core.runnables import RunnablePassthrough
# ----> 8 from langchain_openai import ChatOpenAI, OpenAIEmbeddings
#
# File c:\Users\amith\Documents\GitHub\misc\.venv\lib\site-packages\langchain_openai\__init__.py:3
#       1 """Module for OpenAI integrations."""
# ----> 3 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       4 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       5 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File c:\Users\amith\Documents\GitHub\misc\.venv\lib\site-packages\langchain_openai\chat_models\__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File c:\Users\amith\Documents\GitHub\misc\.venv\lib\site-packages\langchain_openai\chat_models\azure.py:20
#      17 from pydantic import BaseModel, Field, SecretStr, model_validator
#      18 from typing_extensions import Self
# ---> 20 from langchain_openai.chat_models.base import BaseChatOpenAI, _get_default_model_profile
#      22 logger = logging.getLogger(__name__)
#      25 _BM = TypeVar("_BM", bound=BaseModel)
#
# File c:\Users\amith\Documents\GitHub\misc\.venv\lib\site-packages\langchain_openai\chat_models\base.py:43
#      38 import tiktoken
#      39 from langchain_core.callbacks import (
#      40     AsyncCallbackManagerForLLMRun,
#      41     CallbackManagerForLLMRun,
#      42 )
# ---> 43 from langchain_core.language_models import (
#      44     LanguageModelInput,
#      45     ModelProfileRegistry,
#      46 )
#      47 from langchain_core.language_models.chat_models import (
#      48     BaseChatModel,
#      49     LangSmithParams,
#      50 )
#      51 from langchain_core.messages import (
#      52     AIMessage,
#      53     AIMessageChunk,
#    (...)
#      68     is_data_content_block,
#      69 )
#
# ImportError: cannot import name 'ModelProfileRegistry' from 'langchain_core.language_models' (c:\Users\amith\Documents\GitHub\misc\.venv\lib\site-packages\langchain_core\language_models\__init__.py)
