# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.ml.feature import *
from pyspark.ml.classification import *

# %%
spark = SparkSession.builder.appName("Amith").getOrCreate()

# %%
df = spark.read.csv("Exam_Score_Prediction.csv",header=True,inferSchema=True)
df.show()
# Out:
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+
# |student_id|age|gender| course|study_hours|class_attendance|internet_access|sleep_hours|sleep_quality| study_method|facility_rating|exam_difficulty|exam_score|
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+
# |         1| 17|  male|diploma|       2.78|            92.9|            yes|        7.4|         poor|     coaching|            low|           hard|      58.9|
# |         2| 23| other|    bca|       3.37|            64.8|            yes|        4.6|      average|online videos|         medium|       moderate|      54.8|
# |         3| 22|  male|   b.sc|       7.88|            76.8|            yes|        8.5|         poor|     coaching|           high|       moderate|      90.3|
# |         4| 20| other|diploma|       0.67|            48.4|            yes|        5.8|      average|online videos|            low|       moderate|      29.7|
# |         5| 20|female|diploma|       0.89|            71.6|            yes|        9.8|         poor|     coaching|            low|       moderate|      43.7|
# |         6| 23|  male| b.tech|       3.48|            65.4|            yes|        4.2|         good|        mixed|            low|       moderate|      58.2|
# |         7| 17|female| b.tech|       1.35|            69.0|            yes|        7.4|      average|online videos|           high|           hard|      53.7|
# |         8| 22|  male|   b.sc|       5.48|            51.1|            yes|        8.2|         poor|   self-study|            low|       moderate|      47.3|
# |         9| 18| other|    bca|       2.89|            92.0|            yes|        6.6|         poor|   self-study|            low|           easy|      44.9|
# |        10| 17|  male|    bba|       6.77|            44.8|            yes|        9.8|      average|  group study|           high|       moderate|      77.7|
# |        11| 21|female|     ba|       5.99|            86.9|            yes|        5.8|      average|   self-study|         medium|           easy|      63.2|
# |        12| 24|  male|  b.com|       3.77|            96.6|             no|        4.1|         poor|online videos|         medium|           easy|      53.5|
# |        13| 22|female|     ba|       6.76|            46.4|            yes|        8.1|         good|   self-study|         medium|           hard|      63.9|
# |        14| 23|female|    bba|       0.81|            66.0|            yes|        7.1|         poor|online videos|         medium|       moderate|      34.1|
# |        15| 22|  male| b.tech|       4.65|            75.1|            yes|        7.7|         good|  group study|           high|       moderate|      83.5|
# |        16| 23| other|    bba|       4.84|            99.4|            yes|        7.3|      average|     coaching|           high|       moderate|      98.5|
# |        17| 21|  male|   b.sc|       1.97|            91.9|            yes|        8.3|      average|   self-study|         medium|       moderate|      70.3|
# |        18| 18|  male|    bca|        0.4|            64.9|            yes|        6.8|         poor|   self-study|         medium|       moderate|      32.3|
# |        19| 23|female|   b.sc|       4.28|            98.1|            yes|        4.4|      average|        mixed|            low|       moderate|      56.2|
# |        20| 20|  male| b.tech|       4.11|            59.9|            yes|        4.3|         poor|     coaching|           high|       moderate|      49.3|
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- student_id: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- course: string (nullable = true)
#  |-- study_hours: double (nullable = true)
#  |-- class_attendance: double (nullable = true)
#  |-- internet_access: string (nullable = true)
#  |-- sleep_hours: double (nullable = true)
#  |-- sleep_quality: string (nullable = true)
#  |-- study_method: string (nullable = true)
#  |-- facility_rating: string (nullable = true)
#  |-- exam_difficulty: string (nullable = true)
#  |-- exam_score: double (nullable = true)

# %%
for i in df.columns:
    dd = df.select(i)
    print(i,":",dd.filter(col(i).isNull()).count())
# Out:
# student_id : 0
# age : 0
# gender : 0
# course : 0
# study_hours : 0
# class_attendance : 0
# internet_access : 0
# sleep_hours : 0
# sleep_quality : 0
# study_method : 0
# facility_rating : 0
# exam_difficulty : 0
# exam_score : 0

# %%
df_gender = df.groupBy("gender").count()
s = df_gender.agg(sum(col("count"))).first()[0]
df_gender = df_gender.withColumn("percentage",col("count")*100/s)
df_gender.show()
# Out:
# +------+-----+----------+
# |gender|count|percentage|
# +------+-----+----------+
# |female| 6579|    32.895|
# | other| 6726|     33.63|
# |  male| 6695|    33.475|
# +------+-----+----------+

# %%
df_course = df.groupBy("course").count()
s = df_course.agg(sum(col("count"))).first()[0]
df_course = df_course.withColumn("percentage",col("count")*100/s)
df_course.show()
# Out:
# +-------+-----+----------+
# | course|count|percentage|
# +-------+-----+----------+
# |    bca| 2902|     14.51|
# |   b.sc| 2878|     14.39|
# |     ba| 2896|     14.48|
# | b.tech| 2798|     13.99|
# |  b.com| 2864|     14.32|
# |    bba| 2836|     14.18|
# |diploma| 2826|     14.13|
# +-------+-----+----------+

# %%
df.agg(max(col("study_hours"))).show()
df.agg(min(col("study_hours"))).show()
df.agg(median(col("study_hours"))).show()
df.agg(mean(col("study_hours"))).show()
# Out:
# +----------------+
# |max(study_hours)|
# +----------------+
# |            7.91|
# +----------------+
#
# +----------------+
# |min(study_hours)|
# +----------------+
# |            0.08|
# +----------------+
#
# +-------------------+
# |median(study_hours)|
# +-------------------+
# |               4.04|
# +-------------------+
#
# +-----------------+
# | avg(study_hours)|
# +-----------------+
# |4.007603500000015|
# +-----------------+

# %%
df.agg(max(col("class_attendance"))).show()
df.agg(min(col("class_attendance"))).show()
df.agg(median(col("class_attendance"))).show()
df.agg(mean(col("class_attendance"))).show()
# Out:
# +---------------------+
# |max(class_attendance)|
# +---------------------+
# |                 99.4|
# +---------------------+
#
# +---------------------+
# |min(class_attendance)|
# +---------------------+
# |                 40.6|
# +---------------------+
#
# +------------------------+
# |median(class_attendance)|
# +------------------------+
# |                    69.9|
# +------------------------+
#
# +---------------------+
# |avg(class_attendance)|
# +---------------------+
# |    70.01736499999947|
# +---------------------+

# %%
df_internet_access = df.groupBy("internet_access").count()
s = df_course.agg(sum(col("count"))).first()[0]
df_internet_access = df_internet_access.withColumn("percentage",col("count")*100/s)
df_internet_access.show()
# Out:
# +---------------+-----+----------+
# |internet_access|count|percentage|
# +---------------+-----+----------+
# |             no| 3012|     15.06|
# |            yes|16988|     84.94|
# +---------------+-----+----------+

# %%
df.agg(max(col("sleep_hours"))).show()
df.agg(min(col("sleep_hours"))).show()
df.agg(median(col("sleep_hours"))).show()
df.agg(mean(col("sleep_hours"))).show()
# Out:
# +----------------+
# |max(sleep_hours)|
# +----------------+
# |             9.9|
# +----------------+
#
# +----------------+
# |min(sleep_hours)|
# +----------------+
# |             4.1|
# +----------------+
#
# +-------------------+
# |median(sleep_hours)|
# +-------------------+
# |                7.0|
# +-------------------+
#
# +-----------------+
# | avg(sleep_hours)|
# +-----------------+
# |7.008560000000006|
# +-----------------+

# %%
df_sleep_quality = df.groupBy("sleep_quality").count()
s = df_sleep_quality.agg(sum(col("count"))).first()[0]
df_sleep_quality = df_sleep_quality.withColumn("percentage",col("count")*100/s)
df_sleep_quality.show()
# Out:
# +-------------+-----+----------+
# |sleep_quality|count|percentage|
# +-------------+-----+----------+
# |      average| 6694|     33.47|
# |         poor| 6687|    33.435|
# |         good| 6619|    33.095|
# +-------------+-----+----------+

# %%
df_study_method = df.groupBy("study_method").count()
s = df_study_method.agg(sum(col("count"))).first()[0]
df_study_method = df_study_method.withColumn("percentage",col("count")*100/s)
df_study_method.show()
# Out:
# +-------------+-----+----------+
# | study_method|count|percentage|
# +-------------+-----+----------+
# |        mixed| 3894|     19.47|
# |online videos| 4069|    20.345|
# |     coaching| 4036|     20.18|
# |   self-study| 4079|    20.395|
# |  group study| 3922|     19.61|
# +-------------+-----+----------+

# %%
df_facility_rating = df.groupBy("facility_rating").count()
s = df_facility_rating.agg(sum(col("count"))).first()[0]
df_facility_rating = df_facility_rating.withColumn("percentage",col("count")*100/s)
df_facility_rating.show()
# Out:
# +---------------+-----+----------+
# |facility_rating|count|percentage|
# +---------------+-----+----------+
# |            low| 6638|     33.19|
# |           high| 6602|     33.01|
# |         medium| 6760|      33.8|
# +---------------+-----+----------+

# %%
df_exam_difficulty = df.groupBy("exam_difficulty").count()
s = df_exam_difficulty.agg(sum(col("count"))).first()[0]
df_exam_difficulty = df_exam_difficulty.withColumn("percentage",col("count")*100/s)
df_exam_difficulty.show()
# Out:
# +---------------+-----+----------+
# |exam_difficulty|count|percentage|
# +---------------+-----+----------+
# |       moderate| 9878|     49.39|
# |           hard| 3981|    19.905|
# |           easy| 6141|    30.705|
# +---------------+-----+----------+

# %%
df.agg(max(col("exam_score"))).show()
df.agg(min(col("exam_score"))).show()
df.agg(median(col("exam_score"))).show()
df.agg(mean(col("exam_score"))).show()
# Out:
# +---------------+
# |max(exam_score)|
# +---------------+
# |          100.0|
# +---------------+
#
# +---------------+
# |min(exam_score)|
# +---------------+
# |         19.599|
# +---------------+
#
# +------------------+
# |median(exam_score)|
# +------------------+
# |              62.6|
# +------------------+
#
# +-----------------+
# |  avg(exam_score)|
# +-----------------+
# |62.51322500000027|
# +-----------------+

# %%
df.show()
# Out:
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+
# |student_id|age|gender| course|study_hours|class_attendance|internet_access|sleep_hours|sleep_quality| study_method|facility_rating|exam_difficulty|exam_score|
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+
# |         1| 17|  male|diploma|       2.78|            92.9|            yes|        7.4|         poor|     coaching|            low|           hard|      58.9|
# |         2| 23| other|    bca|       3.37|            64.8|            yes|        4.6|      average|online videos|         medium|       moderate|      54.8|
# |         3| 22|  male|   b.sc|       7.88|            76.8|            yes|        8.5|         poor|     coaching|           high|       moderate|      90.3|
# |         4| 20| other|diploma|       0.67|            48.4|            yes|        5.8|      average|online videos|            low|       moderate|      29.7|
# |         5| 20|female|diploma|       0.89|            71.6|            yes|        9.8|         poor|     coaching|            low|       moderate|      43.7|
# |         6| 23|  male| b.tech|       3.48|            65.4|            yes|        4.2|         good|        mixed|            low|       moderate|      58.2|
# |         7| 17|female| b.tech|       1.35|            69.0|            yes|        7.4|      average|online videos|           high|           hard|      53.7|
# |         8| 22|  male|   b.sc|       5.48|            51.1|            yes|        8.2|         poor|   self-study|            low|       moderate|      47.3|
# |         9| 18| other|    bca|       2.89|            92.0|            yes|        6.6|         poor|   self-study|            low|           easy|      44.9|
# |        10| 17|  male|    bba|       6.77|            44.8|            yes|        9.8|      average|  group study|           high|       moderate|      77.7|
# |        11| 21|female|     ba|       5.99|            86.9|            yes|        5.8|      average|   self-study|         medium|           easy|      63.2|
# |        12| 24|  male|  b.com|       3.77|            96.6|             no|        4.1|         poor|online videos|         medium|           easy|      53.5|
# |        13| 22|female|     ba|       6.76|            46.4|            yes|        8.1|         good|   self-study|         medium|           hard|      63.9|
# |        14| 23|female|    bba|       0.81|            66.0|            yes|        7.1|         poor|online videos|         medium|       moderate|      34.1|
# |        15| 22|  male| b.tech|       4.65|            75.1|            yes|        7.7|         good|  group study|           high|       moderate|      83.5|
# |        16| 23| other|    bba|       4.84|            99.4|            yes|        7.3|      average|     coaching|           high|       moderate|      98.5|
# |        17| 21|  male|   b.sc|       1.97|            91.9|            yes|        8.3|      average|   self-study|         medium|       moderate|      70.3|
# |        18| 18|  male|    bca|        0.4|            64.9|            yes|        6.8|         poor|   self-study|         medium|       moderate|      32.3|
# |        19| 23|female|   b.sc|       4.28|            98.1|            yes|        4.4|      average|        mixed|            low|       moderate|      56.2|
# |        20| 20|  male| b.tech|       4.11|            59.9|            yes|        4.3|         poor|     coaching|           high|       moderate|      49.3|
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+
# only showing top 20 rows

# %%
indexer = StringIndexerModel.from_labels(labels=["female","other","male"],inputCol="gender",outputCol="gender_indexed")
df_indexed = indexer.transform(df)
df_indexed = df_indexed.withColumn("gender_indexed",col("gender_indexed")-1)
df_1 = df_indexed.withColumnRenamed("gender_indexed","gender_encoded")
df_1.show()
# Out:
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+--------------+
# |student_id|age|gender| course|study_hours|class_attendance|internet_access|sleep_hours|sleep_quality| study_method|facility_rating|exam_difficulty|exam_score|gender_encoded|
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+--------------+
# |         1| 17|  male|diploma|       2.78|            92.9|            yes|        7.4|         poor|     coaching|            low|           hard|      58.9|           1.0|
# |         2| 23| other|    bca|       3.37|            64.8|            yes|        4.6|      average|online videos|         medium|       moderate|      54.8|           0.0|
# |         3| 22|  male|   b.sc|       7.88|            76.8|            yes|        8.5|         poor|     coaching|           high|       moderate|      90.3|           1.0|
# |         4| 20| other|diploma|       0.67|            48.4|            yes|        5.8|      average|online videos|            low|       moderate|      29.7|           0.0|
# |         5| 20|female|diploma|       0.89|            71.6|            yes|        9.8|         poor|     coaching|            low|       moderate|      43.7|          -1.0|
# |         6| 23|  male| b.tech|       3.48|            65.4|            yes|        4.2|         good|        mixed|            low|       moderate|      58.2|           1.0|
# |         7| 17|female| b.tech|       1.35|            69.0|            yes|        7.4|      average|online videos|           high|           hard|      53.7|          -1.0|
# |         8| 22|  male|   b.sc|       5.48|            51.1|            yes|        8.2|         poor|   self-study|            low|       moderate|      47.3|           1.0|
# |         9| 18| other|    bca|       2.89|            92.0|            yes|        6.6|         poor|   self-study|            low|           easy|      44.9|           0.0|
# |        10| 17|  male|    bba|       6.77|            44.8|            yes|        9.8|      average|  group study|           high|       moderate|      77.7|           1.0|
# |        11| 21|female|     ba|       5.99|            86.9|            yes|        5.8|      average|   self-study|         medium|           easy|      63.2|          -1.0|
# |        12| 24|  male|  b.com|       3.77|            96.6|             no|        4.1|         poor|online videos|         medium|           easy|      53.5|           1.0|
# |        13| 22|female|     ba|       6.76|            46.4|            yes|        8.1|         good|   self-study|         medium|           hard|      63.9|          -1.0|
# |        14| 23|female|    bba|       0.81|            66.0|            yes|        7.1|         poor|online videos|         medium|       moderate|      34.1|          -1.0|
# |        15| 22|  male| b.tech|       4.65|            75.1|            yes|        7.7|         good|  group study|           high|       moderate|      83.5|           1.0|
# |        16| 23| other|    bba|       4.84|            99.4|            yes|        7.3|      average|     coaching|           high|       moderate|      98.5|           0.0|
# |        17| 21|  male|   b.sc|       1.97|            91.9|            yes|        8.3|      average|   self-study|         medium|       moderate|      70.3|           1.0|
# |        18| 18|  male|    bca|        0.4|            64.9|            yes|        6.8|         poor|   self-study|         medium|       moderate|      32.3|           1.0|
# |        19| 23|female|   b.sc|       4.28|            98.1|            yes|        4.4|      average|        mixed|            low|       moderate|      56.2|          -1.0|
# |        20| 20|  male| b.tech|       4.11|            59.9|            yes|        4.3|         poor|     coaching|           high|       moderate|      49.3|           1.0|
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+--------------+
# only showing top 20 rows

# %%
string_indexer = StringIndexer(inputCol="course",outputCol="course_indexed")
one_hot_encoder = OneHotEncoder(inputCol="course_indexed",outputCol="course_encoded")

df_string_indexer = string_indexer.fit(df_1).transform(df_1)
df_one_hot_encoder = one_hot_encoder.fit(df_string_indexer).transform(df_string_indexer)
df_one_hot_encoder.show()
# Out:
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+--------------+--------------+--------------+
# |student_id|age|gender| course|study_hours|class_attendance|internet_access|sleep_hours|sleep_quality| study_method|facility_rating|exam_difficulty|exam_score|gender_encoded|course_indexed|course_encoded|
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+--------------+--------------+--------------+
# |         1| 17|  male|diploma|       2.78|            92.9|            yes|        7.4|         poor|     coaching|            low|           hard|      58.9|           1.0|           5.0| (6,[5],[1.0])|
# |         2| 23| other|    bca|       3.37|            64.8|            yes|        4.6|      average|online videos|         medium|       moderate|      54.8|           0.0|           0.0| (6,[0],[1.0])|
# |         3| 22|  male|   b.sc|       7.88|            76.8|            yes|        8.5|         poor|     coaching|           high|       moderate|      90.3|           1.0|           2.0| (6,[2],[1.0])|
# |         4| 20| other|diploma|       0.67|            48.4|            yes|        5.8|      average|online videos|            low|       moderate|      29.7|           0.0|           5.0| (6,[5],[1.0])|
# |         5| 20|female|diploma|       0.89|            71.6|            yes|        9.8|         poor|     coaching|            low|       moderate|      43.7|          -1.0|           5.0| (6,[5],[1.0])|
# |         6| 23|  male| b.tech|       3.48|            65.4|            yes|        4.2|         good|        mixed|            low|       moderate|      58.2|           1.0|           6.0|     (6,[],[])|
# |         7| 17|female| b.tech|       1.35|            69.0|            yes|        7.4|      average|online videos|           high|           hard|      53.7|          -1.0|           6.0|     (6,[],[])|
# |         8| 22|  male|   b.sc|       5.48|            51.1|            yes|        8.2|         poor|   self-study|            low|       moderate|      47.3|           1.0|           2.0| (6,[2],[1.0])|
# |         9| 18| other|    bca|       2.89|            92.0|            yes|        6.6|         poor|   self-study|            low|           easy|      44.9|           0.0|           0.0| (6,[0],[1.0])|
# |        10| 17|  male|    bba|       6.77|            44.8|            yes|        9.8|      average|  group study|           high|       moderate|      77.7|           1.0|           4.0| (6,[4],[1.0])|
# |        11| 21|female|     ba|       5.99|            86.9|            yes|        5.8|      average|   self-study|         medium|           easy|      63.2|          -1.0|           1.0| (6,[1],[1.0])|
# |        12| 24|  male|  b.com|       3.77|            96.6|             no|        4.1|         poor|online videos|         medium|           easy|      53.5|           1.0|           3.0| (6,[3],[1.0])|
# |        13| 22|female|     ba|       6.76|            46.4|            yes|        8.1|         good|   self-study|         medium|           hard|      63.9|          -1.0|           1.0| (6,[1],[1.0])|
# |        14| 23|female|    bba|       0.81|            66.0|            yes|        7.1|         poor|online videos|         medium|       moderate|      34.1|          -1.0|           4.0| (6,[4],[1.0])|
# |        15| 22|  male| b.tech|       4.65|            75.1|            yes|        7.7|         good|  group study|           high|       moderate|      83.5|           1.0|           6.0|     (6,[],[])|
# |        16| 23| other|    bba|       4.84|            99.4|            yes|        7.3|      average|     coaching|           high|       moderate|      98.5|           0.0|           4.0| (6,[4],[1.0])|
# |        17| 21|  male|   b.sc|       1.97|            91.9|            yes|        8.3|      average|   self-study|         medium|       moderate|      70.3|           1.0|           2.0| (6,[2],[1.0])|
# |        18| 18|  male|    bca|        0.4|            64.9|            yes|        6.8|         poor|   self-study|         medium|       moderate|      32.3|           1.0|           0.0| (6,[0],[1.0])|
# |        19| 23|female|   b.sc|       4.28|            98.1|            yes|        4.4|      average|        mixed|            low|       moderate|      56.2|          -1.0|           2.0| (6,[2],[1.0])|
# |        20| 20|  male| b.tech|       4.11|            59.9|            yes|        4.3|         poor|     coaching|           high|       moderate|      49.3|           1.0|           6.0|     (6,[],[])|
# +----------+---+------+-------+-----------+----------------+---------------+-----------+-------------+-------------+---------------+---------------+----------+--------------+--------------+--------------+
# only showing top 20 rows

# %%
from typing import Any


pt = []
for i in df_one_hot_encoder.select("course_encoded").collect():
    lk = list[Any](i[0])
    for j in lk:
        print(j[0])
    pt.append(lk)
print(pt)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[98], line 8
#       6     lk = list[Any](i[0])
#       7     for j in lk:
# ----> 8         print(j[0])
#       9     pt.append(lk)
#      10 print(pt)
#
# IndexError: invalid index to scalar variable.

# %%
pt[0]
# Out:
# [np.float64(0.0),
#  np.float64(0.0),
#  np.float64(0.0),
#  np.float64(0.0),
#  np.float64(0.0),
#  np.float64(1.0)]
